# %%
import open3d as o3d
import numpy as np
from copy import deepcopy
from pathlib import Path
from typing import List, Tuple


def load_capture_sequence(
    dir_path: Path,
    num_captures: int = None,
) -> Tuple[List[o3d.geometry.PointCloud], List[np.ndarray]]:
    pcd_files = sorted(dir_path.glob("*.ply"))
    pose_files = sorted(dir_path.glob("*.txt"))

    if num_captures:
        pcd_files = pcd_files[:num_captures]
        pose_files = pose_files[:num_captures]

    pcds = [o3d.io.read_point_cloud(str(pcd_file)) for pcd_file in pcd_files]
    poses = [np.loadtxt(str(pose_file)) for pose_file in pose_files]

    if len(pcds) == 0:
        raise Exception("No point clouds found")
    if len(poses) == 0:
        raise Exception("No poses found")
    assert len(pcds) == len(poses)

    print(f"Loaded {len(pcds)} point clouds and {len(poses)} poses")

    return pcds, poses


def multiway_pt2pl_registration(
    pcds: List[o3d.geometry.PointCloud],
    reg_max_correspondence_fine: float,
    global_optimization_max_correspondence: float,
    reg_max_correspondence_coarse: float = None,
) -> o3d.pipelines.registration.PoseGraph:
    pose_graph = o3d.pipelines.registration.PoseGraph()
    odometry = np.identity(4)
    pose_graph.nodes.append(o3d.pipelines.registration.PoseGraphNode(odometry))
    n_pcds = len(pcds)

    for source_id in range(n_pcds):
        for target_id in range(source_id + 1, n_pcds):
            if reg_max_correspondence_coarse is not None:
                icp_coarse = o3d.pipelines.registration.registration_icp(
                    source=pcds[source_id],
                    target=pcds[target_id],
                    max_correspondence_distance=reg_max_correspondence_coarse,
                    init=np.identity(4),
                )
            transformation_icp = o3d.pipelines.registration.registration_icp(
                source=pcds[source_id],
                target=pcds[target_id],
                max_correspondence_distance=reg_max_correspondence_fine,
                init=icp_coarse.transformation,
                estimation_method=o3d.pipelines.registration.TransformationEstimationPointToPlane(),
            ).transformation

            information_icp = o3d.pipelines.registration.get_information_matrix_from_point_clouds(
                source=pcds[source_id],
                target=pcds[target_id],
                max_correspondence_distance=reg_max_correspondence_fine,
                transformation=transformation_icp,
            )
            if target_id == source_id + 1:  # odometry case
                odometry = np.dot(transformation_icp, odometry)
                pose_graph.nodes.append(
                    o3d.pipelines.registration.PoseGraphNode(np.linalg.inv(odometry))
                )
                pose_graph.edges.append(
                    o3d.pipelines.registration.PoseGraphEdge(
                        source_id, target_id, transformation_icp, information_icp, uncertain=False
                    )
                )
            else:  # loop closure case
                pose_graph.edges.append(
                    o3d.pipelines.registration.PoseGraphEdge(
                        source_id, target_id, transformation_icp, information_icp, uncertain=True
                    )
                )
    option = o3d.pipelines.registration.GlobalOptimizationOption(
        max_correspondence_distance=global_optimization_max_correspondence,
        edge_prune_threshold=0.25,
        reference_node=0,
    )

    o3d.pipelines.registration.global_optimization(
        pose_graph,
        o3d.pipelines.registration.GlobalOptimizationLevenbergMarquardt(),
        o3d.pipelines.registration.GlobalOptimizationConvergenceCriteria(),
        option,
    )

    return pose_graph


def downsampled_multiway_pt2pl_registration(
    pcds: List[o3d.geometry.PointCloud],
    voxel_size: float = 0.002,
    reg_dist_max_corr_coarse: float = 0.004,
    reg_dist_max_corr_fine: float = 0.002,
    global_optimization_max_correspondence: float = 0.002,
    visualize: bool = False,
) -> List[o3d.geometry.PointCloud]:
    down_pcds = []
    for i in range(len(pcds)):
        down_pcds.append(deepcopy(pcds[i]).voxel_down_sample(voxel_size=voxel_size))

    if visualize:
        o3d.visualization.draw_geometries(down_pcds, window_name="downsampled for registration")

    pose_graph = multiway_pt2pl_registration(
        down_pcds,
        reg_dist_max_corr_coarse,
        reg_dist_max_corr_fine,
        global_optimization_max_correspondence,
    )

    for point_id in range(len(pcds)):
        print(pose_graph.nodes[point_id].pose)
        pcds[point_id].transform(pose_graph.nodes[point_id].pose)

    if visualize:
        o3d.visualization.draw_geometries(pcds, window_name="registration")

    return pcds


def merge_pcds(point_clouds: List[o3d.geometry.PointCloud]) -> o3d.geometry.PointCloud:
    points = []
    colors = []
    normals = []

    for pcd in point_clouds:
        points.append(np.asarray(pcd.points))

        if pcd.has_colors():
            colors.append(np.asarray(pcd.colors))

        if pcd.has_normals():
            normals.append(np.asarray(pcd.normals))

    merged_pcd = o3d.geometry.PointCloud()
    merged_pcd.points = o3d.utility.Vector3dVector(np.vstack(points))

    if colors:
        merged_pcd.colors = o3d.utility.Vector3dVector(np.vstack(colors))

    if normals:
        merged_pcd.normals = o3d.utility.Vector3dVector(np.vstack(normals))

    return merged_pcd
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
dir_path = Path("/home/huanyu/capture/log2")

# %%
with o3d.utility.VerbosityContextManager(o3d.utility.VerbosityLevel.Debug):
    pcds, tfs = load_capture_sequence(dir_path)

    pcds = [pcd.remove_non_finite_points() for pcd in pcds]
    pcds = [pcd.transform(tf) for pcd, tf in zip(pcds, tfs)]

    marker = o3d.geometry.TriangleMesh.create_coordinate_frame(size=0.1)

    o3d.visualization.draw_geometries(pcds + [marker], window_name="robot coordinate space")

    pcds = [pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)[0] for pcd in pcds]

    o3d.visualization.draw_geometries(pcds, window_name="outlier removal")

    for pcd in pcds:
        pcd.estimate_normals()

    voxel_size = 0.01
    pcds = downsampled_multiway_pt2pl_registration(
        pcds,
        voxel_size=voxel_size,
        reg_dist_max_corr_coarse=voxel_size * 2,
        reg_dist_max_corr_fine=voxel_size,
        global_optimization_max_correspondence=voxel_size,
        visualize=True,
    )

    o3d.visualization.draw_geometries(pcds, window_name="registration")

    merged_pcd = merge_pcds(pcds).voxel_down_sample(voxel_size=0.005)

    o3d.visualization.draw_geometries([merged_pcd], window_name="merged point cloud")
# Out:
# [Open3D DEBUG] Format auto File /home/huanyu/capture/log2/0_2023_10_03__09_43_18_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] [RemoveNonFinitePoints] 2249409 nan points have been removed.
# [Open3D DEBUG] Format auto File /home/huanyu/capture/log2/1_2023_10_03__09_43_31_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] [RemoveNonFinitePoints] 2215963 nan points have been removed.
# [Open3D DEBUG] Format auto File /home/huanyu/capture/log2/2_2023_10_03__09_43_47_pcd.ply
# [Open3D DEBUG] Read geometry::PointCloud: 3145728 vertices.
# [Open3D DEBUG] [RemoveNonFinitePoints] 1989144 nan points have been removed.
# Loaded 3 point clouds and 3 poses
# [Open3D DEBUG] [RemoveNonFinitePoints] 0 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 0 nan points have been removed.
# [Open3D DEBUG] [RemoveNonFinitePoints] 0 nan points have been removed.
# [Open3D DEBUG] GLFW init.
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.7490, -2.1460, -6.4960) - (3.0470, 4.0830, 0.0920)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.7490, -2.1460, -7.2390) - (3.9570, 4.0830, 0.0920)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-2.4563, -2.1460, -7.2390) - (3.9570, 4.0830, 0.0920)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-2.4563, -2.1460, -7.2390) - (3.9570, 4.0830, 0.1000)]
# [Open3D DEBUG] Global colormap init.
# [Open3D DEBUG] [Visualizer] Window closing.
# [Open3D DEBUG] Pointcloud down sampled from 896319 points to 892190 points.
# [Open3D DEBUG] Pointcloud down sampled from 929765 points to 922626 points.
# [Open3D DEBUG] Pointcloud down sampled from 1156584 points to 1138844 points.
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.1320, -1.7860, -4.9990) - (3.0470, 3.3360, 0.0920)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.1320, -1.7860, -4.9990) - (3.9570, 3.3360, 0.0920)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.2524, -2.1370, -5.2228) - (3.9570, 3.3360, 0.0920)]
# [Open3D DEBUG] [Visualizer] Window closing.
# [Open3D DEBUG] Pointcloud down sampled from 892190 points to 198948 points.
# [Open3D DEBUG] Pointcloud down sampled from 922626 points to 228442 points.
# [Open3D DEBUG] Pointcloud down sampled from 1138844 points to 234518 points.
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.1320, -1.7842, -4.9985) - (3.0455, 3.3327, 0.0885)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.1320, -1.7842, -4.9985) - (3.9570, 3.3327, 0.0885)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.2501, -2.1347, -5.2206) - (3.9570, 3.3327, 0.0885)]
# [Open3D DEBUG] [Visualizer] Window closing.
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0089, RMSE 0.0066
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0091, RMSE 0.0066
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0091, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.0092, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.0093, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.0093, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.0093, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.0093, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.0093, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.0094, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.0094, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.0095, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.0095, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.0096, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.0096, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0226, RMSE 0.0124
# [Open3D DEBUG] Residual : 1.07e-04 (# of elements : 4488)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0231, RMSE 0.0124
# [Open3D DEBUG] Residual : 1.06e-04 (# of elements : 4596)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0236, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 4688)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0240, RMSE 0.0121
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 4776)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0245, RMSE 0.0121
# [Open3D DEBUG] Residual : 1.02e-04 (# of elements : 4871)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0250, RMSE 0.0122
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 4980)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0255, RMSE 0.0122
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 5076)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0258, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 5132)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0260, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.06e-04 (# of elements : 5164)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 5205)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.06e-04 (# of elements : 5222)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 5203)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0263, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 5238)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 5218)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5210)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5208)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 5212)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 5219)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 5220)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.0263, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 5232)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.0263, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 5238)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.0263, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 5232)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5221)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5212)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.0262, RMSE 0.0123
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 5212)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.0262, RMSE 0.0122
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5206)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.0261, RMSE 0.0122
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5191)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.0261, RMSE 0.0122
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5200)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.0262, RMSE 0.0122
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5206)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.0261, RMSE 0.0122
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5202)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0111, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0112, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0112, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0113, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0114, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0115, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0115, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0115, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0115, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0115, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0115, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0115, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0116, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0116, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0115, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0115, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0115, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0250, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.07e-04 (# of elements : 4973)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0252, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 5019)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0254, RMSE 0.0119
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 5058)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0257, RMSE 0.0119
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 5115)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0258, RMSE 0.0119
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 5127)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0260, RMSE 0.0119
# [Open3D DEBUG] Residual : 1.06e-04 (# of elements : 5172)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0261, RMSE 0.0119
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 5193)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0263, RMSE 0.0119
# [Open3D DEBUG] Residual : 1.06e-04 (# of elements : 5225)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0264, RMSE 0.0119
# [Open3D DEBUG] Residual : 1.06e-04 (# of elements : 5250)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0266, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.07e-04 (# of elements : 5299)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0268, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.07e-04 (# of elements : 5328)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0269, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.07e-04 (# of elements : 5345)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0272, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.07e-04 (# of elements : 5403)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0275, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.07e-04 (# of elements : 5463)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0278, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.07e-04 (# of elements : 5521)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0282, RMSE 0.0121
# [Open3D DEBUG] Residual : 1.08e-04 (# of elements : 5607)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0285, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.07e-04 (# of elements : 5669)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.0289, RMSE 0.0121
# [Open3D DEBUG] Residual : 1.07e-04 (# of elements : 5754)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.0291, RMSE 0.0121
# [Open3D DEBUG] Residual : 1.06e-04 (# of elements : 5796)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.0292, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 5809)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.0294, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 5846)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.0296, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 5882)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.0296, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5892)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.0297, RMSE 0.0121
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5916)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.0299, RMSE 0.0121
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5946)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.0299, RMSE 0.0121
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5956)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.0299, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5957)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.0300, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 5963)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.0300, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.02e-04 (# of elements : 5964)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.0301, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.02e-04 (# of elements : 5993)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0030, RMSE 0.0067
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0030, RMSE 0.0066
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0030, RMSE 0.0065
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0030, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0030, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0031, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0030, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0030, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0030, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0031, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0031, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0031, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0032, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0032, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0032, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0032, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0033, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.0033, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.0033, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.0033, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.0033, RMSE 0.0063
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.0034, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.0034, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.0034, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.0034, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.0034, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.0034, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.0034, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.0034, RMSE 0.0064
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.0074, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.12e-04 (# of elements : 1685)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.0076, RMSE 0.0121
# [Open3D DEBUG] Residual : 1.11e-04 (# of elements : 1736)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.0077, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.09e-04 (# of elements : 1763)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.0078, RMSE 0.0119
# [Open3D DEBUG] Residual : 1.10e-04 (# of elements : 1791)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.0080, RMSE 0.0120
# [Open3D DEBUG] Residual : 1.11e-04 (# of elements : 1835)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.0082, RMSE 0.0122
# [Open3D DEBUG] Residual : 1.11e-04 (# of elements : 1882)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.0084, RMSE 0.0122
# [Open3D DEBUG] Residual : 1.12e-04 (# of elements : 1927)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.0093, RMSE 0.0122
# [Open3D DEBUG] Residual : 1.12e-04 (# of elements : 2135)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.0102, RMSE 0.0119
# [Open3D DEBUG] Residual : 1.06e-04 (# of elements : 2332)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.0105, RMSE 0.0118
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 2399)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.0107, RMSE 0.0118
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 2433)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.0107, RMSE 0.0117
# [Open3D DEBUG] Residual : 1.01e-04 (# of elements : 2446)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.0108, RMSE 0.0117
# [Open3D DEBUG] Residual : 9.95e-05 (# of elements : 2459)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.0108, RMSE 0.0117
# [Open3D DEBUG] Residual : 9.98e-05 (# of elements : 2478)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.0109, RMSE 0.0116
# [Open3D DEBUG] Residual : 9.95e-05 (# of elements : 2492)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.0109, RMSE 0.0116
# [Open3D DEBUG] Residual : 9.89e-05 (# of elements : 2495)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.0110, RMSE 0.0117
# [Open3D DEBUG] Residual : 9.90e-05 (# of elements : 2507)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.0110, RMSE 0.0116
# [Open3D DEBUG] Residual : 9.75e-05 (# of elements : 2502)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.0110, RMSE 0.0117
# [Open3D DEBUG] Residual : 9.91e-05 (# of elements : 2518)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.0111, RMSE 0.0117
# [Open3D DEBUG] Residual : 1.01e-04 (# of elements : 2531)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.0111, RMSE 0.0116
# [Open3D DEBUG] Residual : 9.97e-05 (# of elements : 2533)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.0111, RMSE 0.0116
# [Open3D DEBUG] Residual : 9.96e-05 (# of elements : 2540)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.0113, RMSE 0.0118
# [Open3D DEBUG] Residual : 1.03e-04 (# of elements : 2577)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.0113, RMSE 0.0118
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 2584)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.0114, RMSE 0.0118
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 2598)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.0115, RMSE 0.0118
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 2618)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.0115, RMSE 0.0118
# [Open3D DEBUG] Residual : 1.04e-04 (# of elements : 2620)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.0115, RMSE 0.0118
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 2636)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.0116, RMSE 0.0118
# [Open3D DEBUG] Residual : 1.05e-04 (# of elements : 2642)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.0116, RMSE 0.0118
# [Open3D DEBUG] Residual : 1.06e-04 (# of elements : 2657)
# [Open3D DEBUG] Validating PoseGraph - finished.
# [Open3D DEBUG] [GlobalOptimizationLM] Optimizing PoseGraph having 3 nodes and 3 edges.
# [Open3D DEBUG] Line process weight : 0.462200
# [Open3D DEBUG] [Initial     ] residual : 1.156349e+02, lambda : 1.545166e+00
# [Open3D DEBUG] [Iteration 00] residual : 4.603598e-01, valid edges : 0, time : 0.000 sec.
# [Open3D DEBUG] Delta.norm() < 1.000000e-06 * (x.norm() + 1.000000e-06)
# [Open3D DEBUG] [GlobalOptimizationLM] total time : 0.000 sec.
# [Open3D DEBUG] [GlobalOptimizationLM] Optimizing PoseGraph having 3 nodes and 2 edges.
# [Open3D DEBUG] Line process weight : 0.393300
# [Open3D DEBUG] [Initial     ] residual : 1.025359e-07, lambda : 1.545165e+00
# [Open3D DEBUG] [Iteration 00] residual : 7.093121e-13, valid edges : 0, time : 0.000 sec.
# [Open3D DEBUG] Current_residual < 1.000000e-06
# [Open3D DEBUG] [GlobalOptimizationLM] total time : 0.000 sec.
# [Open3D DEBUG] CompensateReferencePoseGraphNode : reference : 0
# [[ 1.00000000e+00 -1.71540620e-25  2.06795153e-25  0.00000000e+00]
#  [ 3.52560119e-26  1.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# [[ 0.99935258  0.03452397  0.01012521  0.03088152]
#  [-0.03455986  0.99939688  0.00339055  0.04773468]
#  [-0.01000205 -0.00373828  0.99994299  0.03396711]
#  [ 0.          0.          0.          1.        ]]
# [[ 9.98810629e-01  4.05068316e-02 -2.71389921e-02 -8.30528776e-02]
#  [-4.05425351e-02  9.99177520e-01 -7.66402605e-04  8.09075297e-03]
#  [ 2.70856263e-02  1.86577461e-03  9.99631376e-01  4.24907493e-03]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.1320, -1.7860, -4.9990) - (3.0470, 3.3360, 0.0920)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.1320, -1.7860, -4.9990) - (3.9936, 3.3360, 0.0920)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.2495, -2.1827, -5.1454) - (3.9936, 3.3360, 0.0920)]
# [Open3D DEBUG] [Visualizer] Point size set to 4.00.
# [Open3D DEBUG] [Visualizer] Point size set to 3.00.
# [Open3D DEBUG] [Visualizer] Point size set to 2.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 2.00.
# [Open3D DEBUG] [Visualizer] Window closing.
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.1320, -1.7860, -4.9990) - (3.0470, 3.3360, 0.0920)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.1320, -1.7860, -4.9990) - (3.9936, 3.3360, 0.0920)]
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.2495, -2.1827, -5.1454) - (3.9936, 3.3360, 0.0920)]
# [Open3D DEBUG] [Visualizer] Point size set to 4.00.
# [Open3D DEBUG] [Visualizer] Point size set to 3.00.
# [Open3D DEBUG] [Visualizer] Point size set to 2.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Point size set to 1.00.
# [Open3D DEBUG] [Visualizer] Window closing.
# [Open3D DEBUG] Pointcloud down sampled from 2953660 points to 1866246 points.
# [Open3D DEBUG] Add geometry and update bounding box to [(-1.2495, -2.1827, -5.1454) - (3.9936, 3.3360, 0.0896)]
# [Open3D DEBUG] [Visualizer] Window closing.
